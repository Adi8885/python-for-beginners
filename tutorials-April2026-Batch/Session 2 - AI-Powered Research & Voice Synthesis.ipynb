# %%
# Copyright Aditya Rane
#
# Licensed under the Apache License, Version 2.0 (the "License");
# you may not use this file except in compliance with the License.
# You may obtain a copy of the License at
#
#     https://www.apache.org/licenses/LICENSE-2.0
#
# Unless required by applicable law or agreed to in writing, software
# distributed under the License is distributed on an "AS IS" BASIS,
# WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# See the License for the specific language governing permissions and
# limitations under the License.

# %% [markdown]
# # Session 2: AI-Powered Research & Voice Synthesis
# > This notebook introduces Session 2: AI-Powered Research & Voice Synthesis
#
# <table align="left">
#   <td style="text-align: center">
#     <a href="https://colab.research.google.com/github/Adi8885/python-for-beginners/blob/main//tutorials-April2026-Batch/Session%202%20-%20AI-Powered%20Research%20%26%20Voice%20Synthesis.ipynb">
#       <img src="https://www.gstatic.com/pantheon/images/bigquery/welcome_page/colab-logo.svg" alt="Google Colaboratory logo"><br> Run in Colab
#     </a>
#   </td>
#     <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/colab/import/https://raw.githubusercontent.com/Adi8885/python-for-beginners/refs/heads/main//tutorials-April2026-Batch/Session%202%20-%20AI-Powered%20Research%20%26%20Voice%20Synthesis.ipynb">
#       <img width="32px" src="https://lh3.googleusercontent.com/JmcxdQi-qOpctIvWKgPtrzZdJJK-J3sWE1RsfjZNwshCFgE_9fULcNpuXYTilIR2hjwN" alt="Google Cloud Colab Enterprise logo"><br> Run in Colab Enterprise
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://github.com/Adi8885/python-for-beginners/blob/main//tutorials-April2026-Batch/Session%202%20-%20AI-Powered%20Research%20%26%20Voice%20Synthesis.ipynb">
#       <img src="https://raw.githubusercontent.com/primer/octicons/refs/heads/main/icons/mark-github-24.svg" alt="GitHub logo"><br> View on GitHub
#     </a>
#   </td>
#   <td style="text-align: center">
#     <a href="https://console.cloud.google.com/vertex-ai/workbench/deploy-notebook?download_url=https://raw.githubusercontent.com/Adi8885/python-for-beginners/refs/heads/main//tutorials-April2026-Batch/Session%202%20-%20AI-Powered%20Research%20%26%20Voice%20Synthesis.ipynb">
#       <img src="https://www.gstatic.com/images/branding/gcpiconscolors/vertexai/v1/32px.svg" alt="Vertex AI logo"><br> Open in Vertex AI Workbench
#     </a>
#   </td>
# </table>

# %% [markdown]
# ## Part 1: The Research Thesis - Modern Research Workflow

# %% [markdown]
# ### Research Methodology
#
# | Feature | Traditional Research (Slow, Manual) | Modern Research (Fast, AI-Powered) |
# | :--- | :--- | :--- |
# | **Method** | "Old Way: Googling" | "New Way: AI Analyst" |
# | **Process Steps** | 1. Think of search query<br>2. Open Google<br>3. Click 10+ links<br>4. Read each page<br>5. Take notes manually<br>6. Synthesize information<br>7. Write summary | 1. State your research question<br>2. AI finds relevant sources<br>3. AI reads and analyzes content<br>4. AI synthesizes insights<br>5. AI presents findings |
# | **Time** | 2-3 hours for basic research | 5-10 minutes |
# | **Quality** | Hit or miss, depends on your search skills | Comprehensive, multi-source, structured |

# %% [markdown]
# ### The Research Workflow: The PFAS Framework : Problem → Find → Analyze → Scrape
#
# This framework highlights the evolution from manual "Googling" to leveraging AI as an intelligent research analyst.
#
# ---
#
# #### 1. 🎯 PROBLEM (Define Research Question)
# The quality of your research depends entirely on the clarity of your starting point.
#
# *   **❌ Bad (Too Vague):**
#     `"Tell me about AI"`
# *   **✅ Good (Specific & Actionable):**
#     `"What are the top 3 AI coding assistants in 2024, their pricing models, and which is best for Python development?"`
#
# ---
#
# #### 2. 🔍 FIND (Locate Sources)
# Finding the right data requires more than just clinical search results; it requires source evaluation.
#
# | Method | Traditional: Manual Google Search | AI-Powered: Automatic Discovery |
# | :--- | :--- | :--- |
# | **Action** | Click through pages manually | Searches multiple engines simultaneously |
# | **Trust** | Evaluate credibility on the fly | Automatically filters for high-authority sources |
# | **Depth** | Likely to miss niche/recent sources | Surfaces hidden or brand-new content |
#
# ---
#
# #### 3. 🧠 ANALYZE (Extract Insights)
# Processing information is the most time-consuming phase of traditional research.
#
# | Method | Traditional: Manual Reading | AI-Powered: Intelligent Analysis |
# | :--- | :--- | :--- |
# | **Speed** | Takes hours to read every page | Processes dozens of sources in seconds |
# | **Accuracy** | Easy to miss key points or get tired | Identifies patterns and contradictions instantly |
# | **Context** | Often biased by the first link you click | Synthesizes insights across all found points |
#
# ---
#
# #### 4. 📝 SCRAPE (Gather Data)
# Turning insights into usable, organized data.
#
# | Method | Traditional: Copy-Paste | AI-Powered: Automated Extraction |
# | :--- | :--- | :--- |
# | **Effort** | Highly manual and repetitive | Structured data extraction (JSON, CSV, Tables) |
# | **Formatting** | messy, requires manual cleaning | Clean, standardized formatting from the start |
# | **Structure** | Scattered across multiple notes | Organized and integrated output |

# %% [markdown]
# # ______________________________________________________________________________________________________________________

# %% [markdown]
# ### Part 2: Deep Research Comparison
# #### ChatGPT Deep Research vs. Gemini Deep Research
#
# ---
#
# #### 🤖 ChatGPT Deep Research (GPT-4 / o1)
# *Focuses on high-level reasoning and structured synthesis.*
#
# #### ✅ Strengths
# *   **Superior Reasoning:** Highly logical synthesis of complex topics.
# *   **Coherent Reporting:** Produces very clean, long-form professional reports.
# *   **Framework Adherence:** Excellent at following specific research structures.
# *   **Clean Citations:** Citations are usually well-integrated and easy to verify.
#
# #### ❌ Limitations
# *   **Web Access:** Occasionally limited to more recent or specific indexed pages.
# *   **Context Window:** 128K tokens (~96,000 words).
# *   **Paywalls:** Often blocked by paywalled content.
# *   **Speed:** Can slow down significantly when processing massive datasets.
#
# #### 🎯 Best For
# *   Academic research and literature reviews.
# *   Professional report writing.
# *   Structured competitive analysis.
# *   Citation-heavy documentation.
#
# ---
#
# ### ♊ Gemini Deep Research (Gemini 1.5 Pro)
# *Focuses on scale, multimodal capabilities, and massive data handling.*
#
# #### ✅ Strengths
# *   **Massive Context Window:** 1M+ tokens (~750,000+ words).
# *   **Bulk Processing:** Can ingest entire libraries, books, or technical manuals in one go.
# *   **Data Handling:** Superior at extracting value from large, messy datasets.
# *   **Multimodal:** Native ability to analyze images, videos, and complex PDFs.
# *   **Integration:** Better access to real-time data and Google’s ecosystem.
# *   **Accessibility:** robust free tier options available.
#
# #### ❌ Limitations
# *   **Coherence:** Can occasionally lose focus or become repetitive in extremely long outputs.
# *   **Analysis Paralysis:** Sometimes provides *too* much detail, which can be overwhelming.
#
# #### 🎯 Best For
# *   Analyzing massive document sets (1,000+ pages).
# *   Multi-source research involving video and audio.
# *   Visual content analysis (charts, diagrams, maps).
# *   Developers needing high-limit API access for research.
# ---
#
# ### 📊 Summary Comparison
#
# | Feature | ChatGPT (GPT-4) | Gemini (1.5 Pro) |
# | :--- | :--- | :--- |
# | **Context Window** | 128K Tokens | **1M - 2M Tokens** |
# | **Primary Strength** | Reasoning & Writing | **Scale & Multimodality** |
# | **Media Support** | Text, Images | **Text, Image, Video, PDF** |
# | **Output Style** | Structured & Polished | Detailed & Comprehensive |

# %% [markdown]
# ### Practical Comparison: A Case Study
#
# To understand the real-world difference, let's look at how each AI handles a common research task.
#
# #### 📝 Research Task: *"Analyze customer reviews for iPhone 15"*
#
# | Step | 🤖 ChatGPT Approach | ♊ Gemini Approach |
# | :--- | :--- | :--- |
# | **Step 1** | Locates high-authority recent reviews. | Scours the web for *all* available data points. |
# | **Step 2** | Reads the top 10–20 sources. | Ingests thousands of Reddit comments, YouTube transcripts, and articles. |
# | **Step 3** | Synthesizes key themes manually. | Identifies patterns across a massive, diverse dataset. |
# | **Step 4** | Delivers a concise, well-organized 3-page report. | Delivers a 10-page deep dive with granular nuance. |
#
# **🏆 The Verdict:**
# *   **Winner for Clarity:** ChatGPT (Great for quick, readable summaries).
# *   **Winner for Breadth:** **Gemini** (Great for exhaustive, data-heavy research).
#
# ---
#
# #### 🚀 Why Gemini Often Wins for Research
# The secret weapon is the **Context Window**—the amount of information the AI can "think" about at one time.
#
# ##### Context Window Capacity: At a Glance
#
# #### 🤖 ChatGPT (128K Tokens)
# *   ~10 Blog posts
# *   ~2 Research papers
# *   ~1 Small book
# *   *Limitation:* Often requires "splitting" tasks into smaller chunks.
#
# #### ♊ Gemini (1M Tokens)
# *   **~100** Blog posts
# *   **~20** Research papers
# *   **~5** Entire books
# *   **AN ENTIRE CODEBASE** or thousands of lines of data.
#
# ---
#
# ### 💎 The Gemini Advantage
# 1.  **✅ Maximum Comprehensiveness:** It doesn't just skim; it digests the whole library.
# 2.  **✅ Superior Pattern Detection:** By seeing more data at once, it notices trends that smaller models miss.
# 3.  **✅ Zero Friction:** No more "I need to split this into parts"—just upload everything and ask your question.

# %% [markdown]
# ### 🛠️ MCP with Antigravity
#
# Antigravity leverages the **Model Context Protocol (MCP)** to bridge the gap between AI reasoning and your local machine. This allows the AI to not just "talk" about code, but to actually **do** the work.
#
# ---
#
# #### 🚀 Core MCP Capabilities
# Antigravity automatically enables MCP for:
#
# *   📂 **File System Access:** Creating, reading, and organizing your files.
# *   📦 **Package Management:** Automatically installing necessary libraries (pip, npm, etc.).
# *   💻 **Code Execution:** Running scripts and analyzing outputs in real-time.
# *   🌐 **Web Access:** Searching and fetching real-time data from the internet.
#
# ---
#
# #### 📑 Example Session: Automated Data Analysis
#
# Imagine you give this voice command to Antigravity:
# > *"Create a data analysis script that reads `sales.csv`, calculates monthly revenue, and creates a chart."*
#
# #### **The MCP Workflow in Action:**
#
# 1.  🔍 **[MCP] Verify:** Checks your directory to confirm `sales.csv` exists.
# 2.  📑 **[MCP] Inspect:** Reads the file headers to understand the data structure.
# 3.  🧠 **Generate:** Antigravity writes the customized Python analysis script.
# 4.  🛠️ **[MCP] Environment Check:** Installs `pandas` and `matplotlib` if they aren't already on your system.
# 5.  ⚙️ **[MCP] Execute:** Runs the script automatically in the background.
# 6.  📊 **[MCP] Visualize:** Captures and displays the resulting chart directly in your workspace.
#
# ---
#
# #### 🏆 The Result
# **A fully functional analysis and visualization delivered in under 30 seconds.**
#
# Instead of writing code, debugging imports, and manually running scripts, you simply define the goal and let Antigravity + MCP handle the labor.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Part 4: Voice AI with ElevenLabs
#
# In the world of synthetic speech, ElevenLabs has emerged as the industry leader for high-fidelity, emotionally expressive voice generation.
#
# ---
#
# #### 🎙️ Comparison of Voice AI Services
#
# | Service | Quality | Cost | Voices | API |
# | :--- | :--- | :--- | :--- | :--- |
# | **ElevenLabs** | ⭐⭐⭐⭐⭐ | **$ (Low)** | 100+ | ✅ |
# | **OpenAI TTS** | ⭐⭐⭐⭐ | **$$ (Mid)** | 6 | ✅ |
# | **Amazon Polly** | ⭐⭐⭐ | **$ (Low)** | 60+ | ✅ |
# | **Google TTS** | ⭐⭐⭐ | **$ (Low)** | 50+ | ✅ |
#
# ---
#
# #### 🏆 Why ElevenLabs Wins
#
# ElevenLabs sets itself apart by moving beyond "robotic" text-to-speech, offering a suite of features designed for creators and developers:
#
# *   **✨ Most Natural-Sounding:** Uses advanced deep learning to capture human-like cadence, breathing, and pauses.
# *   **👥 Voice Cloning:** Create a perfect digital replica of your own voice with just 60 seconds of audio.
# *   **🎭 Emotion Control:** Adjust the "stability" and "clarity" to inject excitement, sadness, or authority into the speech.
# *   **🌍 Multilingual Support:** High-quality output across 29+ languages with consistent tonal quality.
# *   **🎁 Generous Free Tier:** Start building immediately with a robust free permanent plan for hobbyists.
#
# ---
#
# **Summary:** While Google and Amazon provide legacy utility, and OpenAI offers simplicity, **ElevenLabs** is the definitive choice for realism and creative control.

# %% [markdown]
# # 🎧 Getting Started with ElevenLabs
#
# Follow these 5 simple steps to integrate industry-leading voice AI into your Python projects.
#
# ---
#
# ### 🔑 Step 1: Create Your Account
# 1.  **Visit:** [elevenlabs.io](https://elevenlabs.io)
# 2.  **Sign Up:** Enjoy the **Free Tier** (10,000 characters/month).
# 3.  **Find Your Key:** Go to `Profile` → `API Key`.
# 4.  **Secure It:** Copy your key and hide it (treat it like a password).
#
# ---
#
# ### 📦 Step 2: Install the Library
# Open your terminal and run:
#
# ```bash
# pip install elevenlabs
# ```
#
# ---
#
# ### 🛠️ Step 3: Basic Usage
# Convert any text to high-quality speech in just a few lines of code.
#
# ```python
# from elevenlabs import generate, play, set_api_key
#
# # 1. Authenticate
# set_api_key("YOUR_API_KEY_HERE")
#
# # 2. Generate Speech
# audio = generate(
#     text="Hello! This is AI-generated speech from ElevenLabs.",
#     voice="Rachel",
#     model="eleven_monolingual_v1"
# )
#
# # 3. Output Options:
# play(audio)  # Play immediately through speakers
#
# # OR Save to file
# with open("output.mp3", "wb") as f:
#     f.write(audio)
# ```
#
# ---
#
# ### 🗣️ Step 4: Explore Available Voices
# Discover the range of pre-made and custom voices available in your library.
#
# ```python
# from elevenlabs import voices
#
# # List all available voices
# all_voices = voices()
#
# print("🎙️ Available Voices:")
# for voice in all_voices:
#     print(f"- {voice.name} | [ID: {voice.voice_id}]")
#
# # Example Output:
# # - Rachel (ID: 21m00Tcm4TlvDq8ikWAM)
# # - Domi (ID: AZnzlk1XvdvUeBnXmlld)
# # - Bella (ID: EXAVITQu4vr4xnSDxMaL)
# ```
#
# ---
#
# ### ✨ Step 5: Advanced Features
# Fine-tune the "personality" of the voice or stream audio for real-time apps.
#
# #### 🎚️ Emotional Control (Voice Settings)
# ```python
# audio = generate(
#     text="I'm so excited about this AI breakthrough!",
#     voice="Rachel",
#     voice_settings={
#         "stability": 0.5,           # Lower = more expressive, Higher = consistent
#         "similarity_boost": 0.75,   # Higher = closer to original voice profile
#         "style": 0.5,               # Accentuate style nuances
#         "use_speaker_boost": True   # Enhances clarity
#     }
# )
# ```
#
# #### 🌊 Low-Latency Streaming
# Ideal for real-time assistants or interactive bots.
#
# ```python
# from elevenlabs import stream
#
# audio_stream = generate(
#     text="This is streaming audio for real-time applications.",
#     voice="Rachel",
#     stream=True
# )
#
# stream(audio_stream)
# ```
#
# ---
#
# > [TIP]
# > **Use Descriptive Voices:** For technical content, try **"Domi"**; for narration, try **"Rachel"** or **"Bella"**. For a deeper cinematic tone, look for **"Adam"**.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # 🎓 Project Summary & Next Steps
#
# Congratulations! You have successfully built a sophisticated AI research and synthesis pipeline. By combining real-time data extraction with advanced generative AI, you've moved from manual "Googling" to automated "Insights."
#
# ---
#
# ### 🚀 What You Built Today
# *   **✅ Web Scraping System:** Automated data collection from the live web.
# *   **✅ AI Analysis with Gemini:** Deep processing of massive datasets across 1 million tokens.
# *   **✅ Voice Synthesis:** Converting text insights into natural, high-fidelity audio using ElevenLabs.
# *   **✅ Research Automation:** A complete end-to-end pipeline that handles the heavy lifting.
# *   **✅ Web Interface:** A visual dashboard to control and monitor the entire process.
#
# ---
#
# ### 🛠️ The Tech Stack
#
# | Technology | Purpose | Key Feature |
# | :--- | :--- | :--- |
# | **Gemini 1.5 Flash** | AI Core & Analysis | **1M Context Window** for massive deep-dives. |
# | **BeautifulSoup** | Data Harvesting | Precision web scraping and data cleaning. |
# | **ElevenLabs** | Human-Like Speech | Industry-leading **neural voice synthesis**. |
# | **MCP** | Logic & Integration | Seamless **File System & Execution** protocol. |
#
# ---
#
# ### 📈 Level Up: Next Steps
#
# 1.  **Expand Data Sources:** Integrate APIs (Twitter/X, Reddit) and internal databases for richer context.
# 2.  **Optimize Performance:** Implement **Caching** mechanisms to avoid redundant scraping and save on API costs.
# 3.  **Go Global:** Add **Multi-language support** for both the analysis and the voice output.
# 4.  **Personalize:** Experiment with **Voice Cloning** to have the AI report findings in *your* own voice.
# 5.  **Scale:** Deploy the application as a **Production Web Service** using Docker or cloud providers.
#
# ---
#
# ### 🔗 Learning Resources
#
# *   **Gemini API:** [ai.google.dev](https://ai.google.dev/)
# *   **ElevenLabs:** [elevenlabs.io](https://elevenlabs.io/)
# *   **MCP Documentation:** [modelcontextprotocol.io](https://modelcontextprotocol.io/)
#
# ---
#
# > [!IMPORTANT]
# > **The best research tool is the one you actually use!**
# > Don't wait for a perfect system. Start simple, gather feedback, and enhance your pipeline iteratively. 🚀

# %%
import os
from elevenlabs.client import ElevenLabs
from IPython.display import Audio, display

# 1. Setup your API Key
# You can also use an environment variable: ELEVENLABS_API_KEY
client = ElevenLabs(
    api_key="sk_5223679d06192bc322495db248919720a5870a7ff4b31ea7" 
)

# 1. Generate audio
audio = client.text_to_speech.convert(
    text="Hello! This is a test.I'm so happy youre able to hear my voice",
    voice_id="JBFqnCBsd6RMkjVDRZzb",
    model_id="eleven_v3",
    output_format="mp3_44100_128",
)
# 2. Extract the bytes from the generator
# ElevenLabs returns a generator, so we need to join it into bytes
audio_bytes = b"".join(audio)
# 3. Play the audio in the notebook
display(Audio(audio_bytes, autoplay=True))
# 4. Save to a file (Optional)
with open("output_audio.mp3", "wb") as f:
    f.write(audio_bytes)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
